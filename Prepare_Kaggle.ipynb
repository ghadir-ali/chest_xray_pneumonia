# %%
# !pip install -U -q kaggle

# %%
# !mkdir -p ~/.kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5525db6e-c551-411f-8389-02b48dbe718b" name="files[]" multiple disabled />
#      <output id="result-5525db6e-c551-411f-8389-02b48dbe718b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"atazmi","key":"7b594346c687cc2db4aafb921f46e09d"}'}

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets list
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# ref                                                         title                                                size  lastUpdated          downloadCount
# ----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# himanshupoddar/zomato-bangalore-restaurants                 Zomato Bangalore Restaurants                         88MB  2019-03-31 09:48:43           8748
# thegurus/spanish-high-speed-rail-system-ticket-pricing      Spanish High Speed Rail tickets pricing - Renfe      27MB  2019-05-10 06:50:30           2483
# taniaj/australian-election-2019-tweets                      Australian Election 2019 Tweets                      29MB  2019-05-21 09:41:38           1479
# brittabettendorf/berlin-airbnb-data                         Berlin Airbnb Data                                   89MB  2019-03-05 09:23:00           2894
# snocco/missing-migrants-project                             Missing Migrants Project                            253KB  2019-04-07 16:57:48           1603
# alvarob96/spanish-stocks-historical-data                    Spanish Stocks Historical Data from 2000 to 2019      1MB  2019-06-07 16:08:00            933
# austinreese/craigslist-carstrucks-data                      Craigslist Cars+Trucks Data                         349MB  2019-06-09 17:34:57           1749
# jlesuffleur/granddebat                                      Le Grand Débat National                             388MB  2019-03-28 21:20:52            200
# mfekadu/darpa-timit-acousticphonetic-continuous-speech      DARPA TIMIT Acoustic-Phonetic Continuous Speech     826MB  2019-06-05 02:01:06            177
# leomauro/smmnet                                             SMMnet                                              105MB  2019-05-13 17:26:55            314
# new-york-city/new-york-city-current-job-postings            New York City Current Job Postings                    3MB  2019-06-30 22:06:04           1864
# new-york-state/nys-environmental-remediation-sites          NYS Environmental Remediation Sites                   3MB  2019-07-03 08:10:37            212
# google/google-landmarks-dataset                             Google-Landmarks Dataset                            107MB  2019-07-03 12:00:35           8406
# datafiniti/womens-shoes-prices                              Women's Shoe Prices                                  12MB  2019-06-24 22:50:14           5654
# sudalairajkumar/chennai-water-management                    Chennai Water Management                             75KB  2019-06-19 03:42:44            879
# matheusfreitag/gas-prices-in-brazil                         Gas Prices in Brazil                                  3MB  2019-06-13 14:35:02            474
# jealousleopard/goodreadsbooks                               Goodreads-books                                     632KB  2019-06-14 16:35:05            943
# eliasdabbas/search-engine-results-flights-tickets-keywords  Search Engine Results - Flights & Tickets Keywords   19MB  2019-07-02 21:49:16            202
# wkirgsn/electric-motor-temperature                          Electric Motor Temperature                           47MB  2019-06-19 11:12:41            426
# r3w0p4/recorded-crime-data-at-police-force-area-level       Recorded Crime Data at the Police Force Area Level  300KB  2019-06-21 15:16:46            331

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading chest-xray-pneumonia.zip to /content
# 100% 1.15G/1.15G [00:07<00:00, 172MB/s]
# 100% 1.15G/1.15G [00:07<00:00, 165MB/s]

# %%
# !ls
# Out:
# chest-xray-pneumonia.zip  kaggle.json  sample_data

# %%
# !unzip chest-xray-pneumonia.zip
# Out:
# Archive:  chest-xray-pneumonia.zip
#   inflating: chest_xray.zip

# %%
# !ls
# Out:
# chest_xray		  chest_xray.zip  __MACOSX
# chest-xray-pneumonia.zip  kaggle.json	  sample_data

# %%
# !unzip chest_xray.zip

# %%
# !ls chest_xray
# Out:
# test  train  val

# %%
import tensorflow as tf
print(tf.__version__)

# %%
print(tf.test.is_gpu_available())
print(tf.test.gpu_device_name())

# %%
# !pip install --upgrade tensorflow-gpu==2.0.0b1

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.is_gpu_available())
print(tf.test.gpu_device_name())
